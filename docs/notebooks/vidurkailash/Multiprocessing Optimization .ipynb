# %%
from multiprocessing import Pool
import numpy as np
from time import time as ts


data = np.zeros((100,10)) # YOUR data: np.array[n_samples x m_features]
n_processes = 4           # YOUR number of processors
def metric(a, b):         # YOUR dist function
    return np.sum(np.abs(a-b)) 


n = data.shape[0]
k_max = n * (n - 1) // 2  # maximum elements in 1D dist array
k_step = n ** 2 // 500    # ~500 bulks
dist = np.zeros(k_max)    # resulting 1D dist array


def proc(start):
    dist = []
    k1 = start
    k2 = min(start + k_step, k_max)
    for k in range(k1, k2):
        # get (i, j) for 2D distance matrix knowing (k) for 1D distance matrix
        i = int(n - 2 - int(np.sqrt(-8 * k + 4 * n * (n - 1) - 7) / 2.0 - 0.5))
        j = int(k + i + 1 - n * (n - 1) / 2 + (n - i) * ((n - i) - 1) / 2)
        # store distance
        a = data[i, :]
        b = data[j, :]
        d = metric(a, b)
        dist.append(d)
    return k1, k2, dist


ts_start = ts()
with Pool(n_processes) as pool:
    for k1, k2, res in pool.imap_unordered(proc, range(0, k_max, k_step)):
        dist[k1:k2] = res
        print("{:.0f} minutes, {:,}..{:,} out of {:,}".format(
            (ts() - ts_start)/60, k1, k2, k_max))


print("Elapsed %.0f minutes" % ((ts() - ts_start) / 60))
print("Saving...")
np.savez("dist.npz", dist=dist)
print("DONE")
# Out:
# 0 minutes, 20..40 out of 4,950
# 0 minutes, 0..20 out of 4,950
# 0 minutes, 60..80 out of 4,950
# 0 minutes, 100..120 out of 4,950
# 0 minutes, 40..60 out of 4,950
# 0 minutes, 80..100 out of 4,950
# 0 minutes, 120..140 out of 4,950
# 0 minutes, 140..160 out of 4,950
# 0 minutes, 160..180 out of 4,950
# 0 minutes, 180..200 out of 4,950
# 0 minutes, 200..220 out of 4,950
# 0 minutes, 220..240 out of 4,950
# 0 minutes, 240..260 out of 4,950
# 0 minutes, 260..280 out of 4,950
# 0 minutes, 280..300 out of 4,950
# 0 minutes, 300..320 out of 4,950
# 0 minutes, 320..340 out of 4,950
# 0 minutes, 340..360 out of 4,950
# 0 minutes, 360..380 out of 4,950
# 0 minutes, 380..400 out of 4,950
# 0 minutes, 400..420 out of 4,950
# 0 minutes, 420..440 out of 4,950
# 0 minutes, 440..460 out of 4,950
# 0 minutes, 480..500 out of 4,950
# 0 minutes, 460..480 out of 4,950
# 0 minutes, 500..520 out of 4,950
# 0 minutes, 540..560 out of 4,950
# 0 minutes, 520..540 out of 4,950
# 0 minutes, 560..580 out of 4,950
# 0 minutes, 600..620 out of 4,950
# 0 minutes, 580..600 out of 4,950
# 0 minutes, 620..640 out of 4,950
# 0 minutes, 640..660 out of 4,950
# 0 minutes, 660..680 out of 4,950
# 0 minutes, 680..700 out of 4,950
# 0 minutes, 700..720 out of 4,950
# 0 minutes, 720..740 out of 4,950
# 0 minutes, 760..780 out of 4,950
# 0 minutes, 740..760 out of 4,950
# 0 minutes, 780..800 out of 4,950
# 0 minutes, 800..820 out of 4,950
# 0 minutes, 820..840 out of 4,950
# 0 minutes, 840..860 out of 4,950
# 0 minutes, 860..880 out of 4,950
# 0 minutes, 880..900 out of 4,950
# 0 minutes, 900..920 out of 4,950
# 0 minutes, 920..940 out of 4,950
# 0 minutes, 940..960 out of 4,950
# 0 minutes, 960..980 out of 4,950
# 0 minutes, 980..1,000 out of 4,950
# 0 minutes, 1,000..1,020 out of 4,950
# 0 minutes, 1,020..1,040 out of 4,950
# 0 minutes, 1,040..1,060 out of 4,950
# 0 minutes, 1,060..1,080 out of 4,950
# 0 minutes, 1,080..1,100 out of 4,950
# 0 minutes, 1,100..1,120 out of 4,950
# 0 minutes, 1,120..1,140 out of 4,950
# 0 minutes, 1,140..1,160 out of 4,950
# 0 minutes, 1,160..1,180 out of 4,950
# 0 minutes, 1,180..1,200 out of 4,950
# 0 minutes, 1,200..1,220 out of 4,950
# 0 minutes, 1,240..1,260 out of 4,950
# 0 minutes, 1,220..1,240 out of 4,950
# 0 minutes, 1,260..1,280 out of 4,950
# 0 minutes, 1,300..1,320 out of 4,950
# 0 minutes, 1,280..1,300 out of 4,950
# 0 minutes, 1,320..1,340 out of 4,950
# 0 minutes, 1,340..1,360 out of 4,950
# 0 minutes, 1,360..1,380 out of 4,950
# 0 minutes, 1,400..1,420 out of 4,950
# 0 minutes, 1,380..1,400 out of 4,950
# 0 minutes, 1,420..1,440 out of 4,950
# 0 minutes, 1,440..1,460 out of 4,950
# 0 minutes, 1,480..1,500 out of 4,950
# 0 minutes, 1,460..1,480 out of 4,950
# 0 minutes, 1,500..1,520 out of 4,950
# 0 minutes, 1,520..1,540 out of 4,950
# 0 minutes, 1,540..1,560 out of 4,950
# 0 minutes, 1,560..1,580 out of 4,950
# 0 minutes, 1,580..1,600 out of 4,950
# 0 minutes, 1,600..1,620 out of 4,950
# 0 minutes, 1,620..1,640 out of 4,950
# 0 minutes, 1,660..1,680 out of 4,950
# 0 minutes, 1,640..1,660 out of 4,950
# 0 minutes, 1,680..1,700 out of 4,950
# 0 minutes, 1,720..1,740 out of 4,950
# 0 minutes, 1,700..1,720 out of 4,950
# 0 minutes, 1,740..1,760 out of 4,950
# 0 minutes, 1,780..1,800 out of 4,950
# 0 minutes, 1,760..1,780 out of 4,950
# 0 minutes, 1,800..1,820 out of 4,950
# 0 minutes, 1,820..1,840 out of 4,950
# 0 minutes, 1,840..1,860 out of 4,950
# 0 minutes, 1,860..1,880 out of 4,950
# 0 minutes, 1,880..1,900 out of 4,950
# 0 minutes, 1,900..1,920 out of 4,950
# 0 minutes, 1,920..1,940 out of 4,950
# 0 minutes, 1,940..1,960 out of 4,950
# 0 minutes, 1,960..1,980 out of 4,950
# 0 minutes, 1,980..2,000 out of 4,950
# 0 minutes, 2,000..2,020 out of 4,950
# 0 minutes, 2,020..2,040 out of 4,950
# 0 minutes, 2,040..2,060 out of 4,950
# 0 minutes, 2,060..2,080 out of 4,950
# 0 minutes, 2,080..2,100 out of 4,950
# 0 minutes, 2,100..2,120 out of 4,950
# 0 minutes, 2,120..2,140 out of 4,950
# 0 minutes, 2,140..2,160 out of 4,950
# 0 minutes, 2,160..2,180 out of 4,950
# 0 minutes, 2,180..2,200 out of 4,950
# 0 minutes, 2,200..2,220 out of 4,950
# 0 minutes, 2,240..2,260 out of 4,950
# 0 minutes, 2,220..2,240 out of 4,950
# 0 minutes, 2,260..2,280 out of 4,950
# 0 minutes, 2,300..2,320 out of 4,950
# 0 minutes, 2,280..2,300 out of 4,950
# 0 minutes, 2,320..2,340 out of 4,950
# 0 minutes, 2,340..2,360 out of 4,950
# 0 minutes, 2,360..2,380 out of 4,950
# 0 minutes, 2,380..2,400 out of 4,950
# 0 minutes, 2,400..2,420 out of 4,950
# 0 minutes, 2,420..2,440 out of 4,950
# 0 minutes, 2,440..2,460 out of 4,950
# 0 minutes, 2,460..2,480 out of 4,950
# 0 minutes, 2,480..2,500 out of 4,950
# 0 minutes, 2,500..2,520 out of 4,950
# 0 minutes, 2,520..2,540 out of 4,950
# 0 minutes, 2,540..2,560 out of 4,950
# 0 minutes, 2,560..2,580 out of 4,950
# 0 minutes, 2,580..2,600 out of 4,950
# 0 minutes, 2,600..2,620 out of 4,950
# 0 minutes, 2,620..2,640 out of 4,950
# 0 minutes, 2,640..2,660 out of 4,950
# 0 minutes, 2,660..2,680 out of 4,950
# 0 minutes, 2,680..2,700 out of 4,950
# 0 minutes, 2,700..2,720 out of 4,950
# 0 minutes, 2,720..2,740 out of 4,950
# 0 minutes, 2,740..2,760 out of 4,950
# 0 minutes, 2,780..2,800 out of 4,950
# 0 minutes, 2,760..2,780 out of 4,950
# 0 minutes, 2,800..2,820 out of 4,950
# 0 minutes, 2,820..2,840 out of 4,950
# 0 minutes, 2,840..2,860 out of 4,950
# 0 minutes, 2,860..2,880 out of 4,950
# 0 minutes, 2,880..2,900 out of 4,950
# 0 minutes, 2,900..2,920 out of 4,950
# 0 minutes, 2,920..2,940 out of 4,950
# 0 minutes, 2,940..2,960 out of 4,950
# 0 minutes, 2,960..2,980 out of 4,950
# 0 minutes, 2,980..3,000 out of 4,950
# 0 minutes, 3,000..3,020 out of 4,950
# 0 minutes, 3,020..3,040 out of 4,950
# 0 minutes, 3,040..3,060 out of 4,950
# 0 minutes, 3,060..3,080 out of 4,950
# 0 minutes, 3,080..3,100 out of 4,950
# 0 minutes, 3,100..3,120 out of 4,950
# 0 minutes, 3,120..3,140 out of 4,950
# 0 minutes, 3,140..3,160 out of 4,950
# 0 minutes, 3,160..3,180 out of 4,950
# 0 minutes, 3,200..3,220 out of 4,950
# 0 minutes, 3,180..3,200 out of 4,950
# 0 minutes, 3,220..3,240 out of 4,950
# 0 minutes, 3,240..3,260 out of 4,950
# 0 minutes, 3,260..3,280 out of 4,950
# 0 minutes, 3,280..3,300 out of 4,950
# 0 minutes, 3,300..3,320 out of 4,950
# 0 minutes, 3,320..3,340 out of 4,950
# 0 minutes, 3,340..3,360 out of 4,950
# 0 minutes, 3,360..3,380 out of 4,950
# 0 minutes, 3,380..3,400 out of 4,950
# 0 minutes, 3,400..3,420 out of 4,950
# 0 minutes, 3,420..3,440 out of 4,950
# 0 minutes, 3,440..3,460 out of 4,950
# 0 minutes, 3,460..3,480 out of 4,950
# 0 minutes, 3,480..3,500 out of 4,950
# 0 minutes, 3,500..3,520 out of 4,950
# 0 minutes, 3,520..3,540 out of 4,950
# 0 minutes, 3,540..3,560 out of 4,950
# 0 minutes, 3,560..3,580 out of 4,950
# 0 minutes, 3,580..3,600 out of 4,950
# 0 minutes, 3,600..3,620 out of 4,950
# 0 minutes, 3,620..3,640 out of 4,950
# 0 minutes, 3,640..3,660 out of 4,950
# 0 minutes, 3,660..3,680 out of 4,950
# 0 minutes, 3,680..3,700 out of 4,950
# 0 minutes, 3,700..3,720 out of 4,950
# 0 minutes, 3,720..3,740 out of 4,950
# 0 minutes, 3,740..3,760 out of 4,950
# 0 minutes, 3,760..3,780 out of 4,950
# 0 minutes, 3,780..3,800 out of 4,950
# 0 minutes, 3,800..3,820 out of 4,950
# 0 minutes, 3,820..3,840 out of 4,950
# 0 minutes, 3,860..3,880 out of 4,950
# 0 minutes, 3,840..3,860 out of 4,950
# 0 minutes, 3,880..3,900 out of 4,950
# 0 minutes, 3,900..3,920 out of 4,950
# 0 minutes, 3,920..3,940 out of 4,950
# 0 minutes, 3,940..3,960 out of 4,950
# 0 minutes, 3,960..3,980 out of 4,950
# 0 minutes, 3,980..4,000 out of 4,950
# 0 minutes, 4,000..4,020 out of 4,950
# 0 minutes, 4,020..4,040 out of 4,950
# 0 minutes, 4,040..4,060 out of 4,950
# 0 minutes, 4,060..4,080 out of 4,950
# 0 minutes, 4,080..4,100 out of 4,950
# 0 minutes, 4,100..4,120 out of 4,950
# 0 minutes, 4,120..4,140 out of 4,950
# 0 minutes, 4,140..4,160 out of 4,950
# 0 minutes, 4,160..4,180 out of 4,950
# 0 minutes, 4,180..4,200 out of 4,950
# 0 minutes, 4,200..4,220 out of 4,950
# 0 minutes, 4,220..4,240 out of 4,950
# 0 minutes, 4,240..4,260 out of 4,950
# 0 minutes, 4,260..4,280 out of 4,950
# 0 minutes, 4,280..4,300 out of 4,950
# 0 minutes, 4,300..4,320 out of 4,950
# 0 minutes, 4,320..4,340 out of 4,950
# 0 minutes, 4,340..4,360 out of 4,950
# 0 minutes, 4,360..4,380 out of 4,950
# 0 minutes, 4,380..4,400 out of 4,950
# 0 minutes, 4,400..4,420 out of 4,950
# 0 minutes, 4,420..4,440 out of 4,950
# 0 minutes, 4,440..4,460 out of 4,950
# 0 minutes, 4,460..4,480 out of 4,950
# 0 minutes, 4,480..4,500 out of 4,950
# 0 minutes, 4,500..4,520 out of 4,950
# 0 minutes, 4,520..4,540 out of 4,950
# 0 minutes, 4,540..4,560 out of 4,950
# 0 minutes, 4,560..4,580 out of 4,950
# 0 minutes, 4,580..4,600 out of 4,950
# 0 minutes, 4,600..4,620 out of 4,950
# 0 minutes, 4,620..4,640 out of 4,950
# 0 minutes, 4,640..4,660 out of 4,950
# 0 minutes, 4,660..4,680 out of 4,950
# 0 minutes, 4,680..4,700 out of 4,950
# 0 minutes, 4,700..4,720 out of 4,950
# 0 minutes, 4,720..4,740 out of 4,950
# 0 minutes, 4,740..4,760 out of 4,950
# 0 minutes, 4,760..4,780 out of 4,950
# 0 minutes, 4,780..4,800 out of 4,950
# 0 minutes, 4,800..4,820 out of 4,950
# 0 minutes, 4,820..4,840 out of 4,950
# 0 minutes, 4,840..4,860 out of 4,950
# 0 minutes, 4,860..4,880 out of 4,950
# 0 minutes, 4,880..4,900 out of 4,950
# 0 minutes, 4,940..4,950 out of 4,950
# 0 minutes, 4,900..4,920 out of 4,950
# 0 minutes, 4,920..4,940 out of 4,950
# Elapsed 0 minutes
# Saving...
# DONE
