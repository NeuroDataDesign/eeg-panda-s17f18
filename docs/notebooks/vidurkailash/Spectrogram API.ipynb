# %%
import numpy as np 
import pandas as pd
import pickle
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import tools

init_notebook_mode(connected=True)

print __version__ 
import plotly.plotly as py
import plotly.graph_objs as go
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 2.0.8

# %%
def spectrograms(D, p_global, p_local):
    F_s = p_global['sample_freq']
    Patient_ID = p_global['patient_id']
    Title = p_local['paradigm']
    Data = D[Title]
    
    
    disp_chans = range(Data.shape[0])
    if 'disp_chans' in p_local.keys():
        disp_chans = p_local['disp_chans']
    
    
    F_s = 500 # sampling freq
    dt = 1./F_s

    for i in disp_chans:
        sample_points = np.arange(Data.shape[1]) * dt
        signal = Data[i, :]
        ft = np.fft.fft(signal) * dt
        ft = ft[: len(sample_points)/2]
        freq = np.fft.fftfreq(len(sample_points), dt)
        freq = freq[:len(sample_points)/2]

        
        data = [dict(
            visible = False,
            line=dict(color='00CED1', width=6),
#             name = '𝜈 = '+str(step),
            x = freq[:2000],
            y = np.abs(ft)[:2000],
            mode = 'markers')]
    
    xaxis = dict(
        title = 'Time  seconds timestamps)'
    )
    yaxis = dict(
        title = 'Intensity (microVolts)'
    )

    layout = dict(xaxis=xaxis, yaxis=yaxis)
    
    fig= go.Figure(data=data, layout=layout)
    iplot(fig)
#         steps = []
#     for i in range(len(data)):
#         step = dict(
#             method = 'restyle',
#             args = ['visible', [False] * len(data)],
#         )
#         step['args'][1][i] = True # Toggle i'th trace to "visible"
#         steps.append(step)

#     sliders = [dict(
#         active = 10,
#         currentvalue = {"prefix": "Electrode: "},
#         pad = {"t": 50},
#         steps = steps
#     )]

#     layout = dict(sliders=sliders)

#     fig = dict(data=data, layout=layout)
        

        
#     fig= go.Figure(data=data, layout=layout)
#     iplot(fig)

# %%
test_global = {
    'sample_freq': 500,
    'patient_id': 'NDARAA075AMK'
}

test_local = {
    'paradigm': 'video1',
    'disp_chans': [0, 2, 4]
}

# %%
import sys
sys.path.append('../../../code/scripts')
from data_interact import get_patient

# %%
patient = get_patient('NDARAA075AMK')

# %%
spectrograms(patient, test_global, test_local)
# Out:
# <div id="74b07790-ff67-4613-9f05-4a101485ad75" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("74b07790-ff67-4613-9f05-4a101485ad75", [{"visible": false, "mode": "markers", "y": [616554.9879072265, 9317.06421577995, 14066.169081118847, 12288.504068896575, 11796.531501145431, 6728.283148194154, 6788.726855297112, 6502.150025078816, 4429.11935758389, 4680.29033667306, 3002.747109009755, 3162.9528205072043, 3303.1836397569123, 1819.3928768946664, 3102.5195752841314, 2118.4712901083712, 1410.2928911742692, 1813.5158248188334, 1608.7182911348286, 1521.9499643275017, 1676.579921687926, 1223.324917577917, 1779.3357674589377, 861.7770534249452, 998.7905980463679, 1642.1897530065764, 885.1477181449869, 1363.1235092063084, 1284.022688513581, 1035.887668735632, 1299.5044957590633, 849.3490460541889, 1360.7437