# %% [markdown]
# Basic Imports

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import pickle

# %% [markdown]
# Import Plot.ly

# %%
#comparing plotly vs bokeh
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import tools

init_notebook_mode(connected=True)

print __version__
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 2.0.8

# %% [markdown]
# Import Bokeh

# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure 
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="80eaa3fb-d1c8-4c6f-aacb-0e2b26232692">Loading BokehJS ...</span>
#     </div>

# %%
NDARAA075AMK = {}

# %%
NDARAA075AMK['video1'] = pickle.load( open( "../../../data/NDARAA075AMK/EEG/raw/PANDA/NDARAA075AMK_Video1_data.pkl", "rb" ) )

# %%
NDARAA075AMK['video1'].shape
# Out:
# (128, 59500)

# %%
NDARAA075AMK['video1'][0, ::50]
# Out:
# array([-23874., -23887., -23885., ..., -23996., -24002., -24024.], dtype=float32)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
F_s = 500 # sampling freq
dt = 1./F_s

fig = tools.make_subplots(rows=2, cols=5)

for i in range(10):
    sample_points = np.arange(NDARAA075AMK['video1'].shape[1]) * dt
    signal = NDARAA075AMK['video1'][i, :]
    ft = np.fft.fft(signal) * dt
    ft = ft[: len(sample_points)/2]
    freq = np.fft.fftfreq(len(sample_points), dt)
    freq = freq[:len(sample_points)/2]

    trace = go.Scatter(
        x = freq[:2000],
        y = np.abs(ft)[:2000],
        mode = 'markers'
    )
    
    fig.append_trace(trace, i / 5 + 1, i % 5 + 1)
    
#     data = [trace]
    
# layout = go.Layout(
#     title = 'Frequency Spectrum, All Channels', 
#     hovermode = 'closest', 
#     xaxis = dict(
#         title = 'Hz',
#         range = [0, 10]
#         ), 
#     yaxis = dict(
#         title = 'Magnitude',
#         range = [0, 1000]
#         )
# )

    fig['layout'].update(
        title = 'Frequency Spectrum, All Channels', 
    #     hovermode = 'closest', 
        xaxis = dict(
            title = 'Hz',
            range = [0, 10]
            ), 
        yaxis = dict(
            title = 'Magnitude',
            range = [0, 1000]
            )
    )
iplot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]    [ (1,2) x2,y2 ]    [ (1,3) x3,y3 ]    [ (1,4) x4,y4 ]    [ (1,5) x5,y5 ]
# [ (2,1) x6,y6 ]    [ (2,2) x7,y7 ]    [ (2,3) x8,y8 ]    [ (2,4) x9,y9 ]    [ (2,5) x10,y10 ]
# <div id="15c2cf9c-f3b5-4b86-82bb-19eb89d9adab" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("15c2cf9c-f3b5-4b86-82bb-19eb89d9adab", [{"yaxis": "y1", "mode": "markers", "xaxis": "x1", "y": [2774118.4960000003, 58983.46680713321, 24634.787352028925, 16076.188484108357, 7087.397920394066, 1201.857114470739, 3069.1985811462146, 2023.220080967195, 1780.8161422285364, 1098.618712072127, 1012.3725438605278, 792.6110948331258, 1311.116380205314, 626.6257511969593, 1498.5450010230213, 770.9342131630947, 811.6599722053044, 295.0315628823007, 280.24258830968694, 349.883160256995, 292.8046144348362, 675.2960210586159, 590.9859258873024, 497.1100018721321, 903.1320109080235, 128.0446520181473, 696.3658503009797, 265.4770562232448, 373.59203526701396, 321.2705655890087, 287.30930719249227, 537.083309956706, 308.81335793976444, 387.0829784955926, 405.80225146656306, 285.46479980440455, 124.42322838575892, 159.49303629270392, 336.0796975715774, 181.53126497829473, 324.10904339798964, 533.820337236584, 470.4790552125854, 289.46856795580686, 477.4759477527203, 504.53871219283315, 64.6608074979581, 142.26891312928007, 273.831833240513, 186.3166204171132, 443.498014531548, 605.7192243830142, 329.9692873601433, 445.0075232011021, 325.9444307614704, 30.944315033707426, 342.4629407251909, 42.14855044675292, 308.59189071048854, 259.6239374111918, 230.2275664733819, 110.3480461949253, 295.42281760736097, 35.08403376187776, 61.24267679565517, 205.20168413352548, 217.0382222711329, 86.55995372349479, 292.84040508550294, 87.84739447094928, 307.9155963044021, 287.29812288174855, 83.43640623586212, 52.82701102540462, 11.987265538639507, 74.74204719225655, 141.42096044354082, 98.3212426395252, 161.71292664669963, 199.6907359876275, 168.04843187138763, 61.965309385300145, 74.35368636600016, 91.83987492482052, 138.08907574622452, 179.95524400313815, 43.05928756421821, 69.67617810577413, 178.38098016746082, 211.60937736159616, 198.34602494081275, 154.23221501059172, 237.98062768451183, 122.43252406478537, 91.22940950525185, 130.20523681894568, 254.29714792257084, 144.74270808233427, 99.2792144706452, 173.12166137128872, 246.2497065100088, 36.03510760377521, 202.81004971305248, 140.69036606678642, 144.12265908331523, 94.09854335809442, 243.71286734158554, 215.39529159565046, 198.23324801218698, 327.5803254960086, 102.65433313654056, 110.76519813761846, 46.854303885476966, 77.6865619610911, 190.81079348492213, 85.175009252629, 53.232513811456826, 180.73828655816294, 153.49183537695822, 93.51449171991125, 132.2153319691801, 73.90973568278818, 142.39051699432213, 202.49122577502186, 155.974505925326, 216.30740921616874, 157.24432305016478, 61.47980514772598, 118.30377566644044, 13.210275661172918, 73.19274971667554, 124.64934872193281, 110.59516433440292, 140.83281812964813, 58.8778379343475, 135.7316076108881, 41.92608643201302, 36.01416372908332, 128.0222518699969, 86.73504718745932, 145.19073905565082, 79.28167095488561, 78.87034533015802, 79.74877698130759, 58.675242919048344, 103.9225548642551, 79.76466030771061, 141.24766428000746, 142.65977472074525, 43.68591467701683, 72.60175235638056, 83.91659759003696, 53.8209591385425, 153.1842132378156, 118.19403901094155, 16.844169044638804, 24.826534272746024, 81.307154636941, 189.6573471115987, 123.05614536189806, 67.8022876124585, 18.696970369408994, 82.10322984053242, 80.36001569445627, 172.6652191398543, 78.6354372678052, 76.00483602448685, 139.2820008024427, 73.3748461829469, 72.92812834282878, 132.84747245722428, 31.84669632915274, 93.15573572802788, 64.49918502948204, 72.62330174555929, 129.46772038162874, 57.82349673869761, 183.6458425021705, 72.18955896466196, 134.82038288263337, 66.73082585641008, 102.57470344464296, 78.27765236118216, 63.142263718705316, 60.035963081571644, 158.53023776759173, 49.12355779200663, 11.77 ...

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.models import Range1d
from bokeh.models import Title

# %%
F_s = 500 # sampling freq
dt = 1./F_s

for i in range(11):
    sample_points = np.arange(NDARAA075AMK['video1'].shape[1]) * dt
    signal = NDARAA075AMK['video1'][i, :]
    ft = np.fft.fft(signal) * dt
    ft = ft[: len(sample_points)/2]
    freq = np.fft.fftfreq(len(sample_points), dt)
    freq = freq[:len(sample_points)/2]
    
    x = freq[:2000];
    y = np.abs(ft)[:2000];
    
    p = figure(title= 'Frequency Spectrum, Channel ' + str(i), plot_width=1000, x_range=(0,10))
    p.y_range= Range1d(0,1000)
    p.circle(x, y, size=5)
    p.add_layout(Title(text='Magnitude', align='center'), 'left')
    p.add_layout(Title(text='Hz', align='center'), 'below')
    
    print(i)
    show(p)
# Out:
# 0
# <div class="bk-root">
#     <div class="bk-plotdiv" id="dd9fdfb5-c77a-4ccf-be8c-1dc59bdaa97a"></div>
# </div>
# 1
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e486a60c-ea4a-48dc-9085-78348f81b6d5"></div>
# </div>
# 2
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e8c4d6b1-1306-4afc-8134-73999a67505c"></div>
# </div>
# 3
# <div class="bk-root">
#     <div class="bk-plotdiv" id="bf2e8001-4512-4567-a768-5db4e496e345"></div>
# </div>
# 4
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1e1f9a69-88ee-40bc-8699-d59c70d9d766"></div>
# </div>
# 5
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f6e108bb-1c44-4a17-9c85-9e1d509fd422"></div>
# </div>
# 6
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ed925d06-2378-4cd1-bbeb-f80b979366ac"></div>
# </div>
# 7
# <div class="bk-root">
#     <div class="bk-plotdiv" id="eaecc93d-6b09-497f-997c-cb95d59ac212"></div>
# </div>
# 8
# <div class="bk-root">
#     <div class="bk-plotdiv" id="60868d9d-94bf-4a3a-a66a-0133886d3231"></div>
# </div>
# 9
# <div class="bk-root">
#     <div class="bk-plotdiv" id="98692269-4bfc-4c11-8fd9-7b0b84da19c8"></div>
# </div>
# 10
# <div class="bk-root">
#     <div class="bk-plotdiv" id="402f6562-3f91-42be-a8f4-16bfecba845a"></div>
# </div>
