# %%
# %gui notebook

# %%
from mayavi import mlab
import numpy as np

# Calculate the Julia set on a grid
x, y = np.ogrid[-1.5:0.5:500j, -1:1:500j]
z = x + 1j * y

julia = np.zeros(z.shape)

for i in range(50):
    z = z ** 2 - 0.70176 - 0.3842j
    julia += 1 / float(2 + i) * (z * np.conj(z) > 4)

# Display it
mlab.figure(size=(400, 300))
mlab.surf(julia, colormap='gist_earth', warp_scale='auto', vmax=1.5)

# A view into the "Canyon"
mlab.view(65, 27, 322, [30., -13.7,  136])
mlab.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f9970c227ab1> in <module>()
# ----> 1 from mayavi import mlab
#       2 import numpy as np
#       3
#       4 # Calculate the Julia set on a grid
#       5 x, y = np.ogrid[-1.5:0.5:500j, -1:1:500j]
#
# /usr/local/lib/python2.7/dist-packages/mayavi/mlab.py in <module>()
#      25
#      26 # Mayavi imports
# ---> 27 from mayavi.tools.camera import view, roll, yaw, pitch, move
#      28 from mayavi.tools.figure import figure, clf, gcf, savefig, \
#      29     draw, sync_camera, close, screenshot
#
# /usr/local/lib/python2.7/dist-packages/mayavi/tools/camera.py in <module>()
#      23 # We can't use gcf, as it creates a circular import in camera management
#      24 # routines.
# ---> 25 from .engine_manager import get_engine
#      26
#      27
#
# ...

# %%
from surfer import Brain
subject_id = 'fsf02anat'
hemi = 'lh'
surf = 'inflated'
sdir = '/home/ryan/fs_data/fsfast-tutorial.subjects'
brain = Brain(subject_id, hemi, surf, subjects_dir = sdir)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b60d0cf0d358> in <module>()
# ----> 1 from surfer import Brain
#       2 subject_id = 'fsf02anat'
#       3 hemi = 'lh'
#       4 surf = 'inflated'
#       5 sdir = '/home/ryan/fs_data/fsfast-tutorial.subjects'
#
# /usr/local/lib/python2.7/dist-packages/surfer/__init__.py in <module>()
# ----> 1 from .viz import Brain, TimeViewer  # noqa
#       2 from .utils import Surface, verbose, set_log_level, set_log_file  # noqa
#       3 from .io import project_volume_data  # noqa
#       4
#       5 __version__ = "0.8.0"
#
# /usr/local/lib/python2.7/dist-packages/surfer/viz.py in <module>()
#       9 import nibabel as nib
#      10
# ---> 11 from mayavi import mlab
#      12 from mayavi.tools.mlab_scene_model import MlabSceneModel
#      13 from mayavi.core import lut_manager
#
# ...
